# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import pandas as pd
import csv
from pathlib import Path
import os



def clean_data(subjn, ctal, eegtype, runn):
    subjectfile = f'dataset2/sub-HUP{subjn}/ses-presurgery/ieeg/sub-HUP{subjn}_ses-presurgery_task-{ctal}_acq-{eegtype}_run-0{runn}_'
    edf = mne.io.read_raw_edf(f'{subjectfile}ieeg.edf')
    header = ','.join(edf.ch_names)
    np.savetxt(f'{subjn}_{ctal}_{runn}_ieeg.csv', edf.get_data().T, delimiter=',', header=header)
    df = pd.read_csv(f'{subjn}_{ctal}_{runn}_ieeg.csv')
    channelfile = pd.read_csv(f'{subjectfile}channels.tsv', sep='\t')
    channelfile = channelfile[channelfile['status'] != 'bad']
    df = df[channelfile['name'].tolist()]
    # df.plot()
    df.to_csv(f'cleaned/{subjn}_{ctal}_{runn}_ieeg.csv', index=False)
    #plt.show()

    #'060', '064', '065', '070', '074', '075', '080', '082', '086', '087', '088', '089', '094', '097',
               #'133', '134', # '135', '105', '106', '107','111', '112', '114', '116', '117', '123', 
                 # '126', '130','138', '139', '140', '141', '142', '144', '146', '148', '150', '151', '157', 
                

subjectlist = [ '158', '160', '162',
               '162', '163', '164', '165', '166', '171', '173', '173', '177', '179', '180', '181', '185', '187',
               '188', '190']

for subject in subjectlist:
    for run in [1, 2, 3, 4, 5]:
            if (os.path.exists(f'dataset2/sub-HUP{subject}/ses-presurgery/ieeg/sub-HUP{subject}_ses-presurgery_task-ictal_acq-seeg_run-0{run}_ieeg.edf')):
                #dataset2/sub-HUP144/ses-presurgery/ieeg/sub-HUP144_ses-presurgery_task-ictal_acq-seeg_run-01_
                try:
                    clean_data(subject, 'ictal', 'seeg', run)
                except:
                    continue
            if (os.path.exists(f'dataset2/sub-HUP{subject}/ses-presurgery/ieeg/sub-HUP{subject}_ses-presurgery_task-interictal_acq-seeg_run-0{run}_ieeg.edf')):
                try:
                    clean_data(subject, 'interictal', 'seeg', run)
                except:
                    continue
            if (os.path.exists(f'dataset2/sub-HUP{subject}/ses-presurgery/ieeg/sub-HUP{subject}_ses-presurgery_task-ictal_acq-ecog_run-0{run}_ieeg.edf')):
                try:
                    clean_data(subject, 'ictal', 'ecog', run)
                except:
                    continue
            if (os.path.exists(f'dataset2/sub-HUP{subject}/ses-presurgery/ieeg/sub-HUP{subject}_ses-presurgery_task-interictal_acq-ecog_run-0{run}_ieeg.edf')):
                try:
                   clean_data(subject, 'interictal', 'ecog', run)
                except:
                    continue
# Out:
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HUP146/ses-presurgery/ieeg/sub-HUP146_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HUP146/ses-presurgery/ieeg/sub-HUP146_ses-presurgery_task-interictal_acq-seeg_run-01_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HUP146/ses-presurgery/ieeg/sub-HUP146_ses-presurgery_task-ictal_acq-seeg_run-02_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HUP146/ses-presurgery/ieeg/sub-HUP146_ses-presurgery_task-interictal_acq-seeg_run-02_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HUP146/ses-presurgery/ieeg/sub-HUP146_ses-presurgery_task-ictal_acq-seeg_run-03_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /Users/zr918/Documents/Data Science Practicum/finalproject/dataset2/sub-HU