# %% [markdown]
# STE Detector

# %%
import numpy as np
import mne
edf = mne.io.read_raw_edf('C:\\Users\\washi\\OneDrive\\Documents\\Final Project\\sub-HUP060\\ses-presurgery\\ieeg\\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf')
header = ','.join(edf.ch_names)
np.savetxt('test1.csv', edf.get_data().T, delimiter=',', header=header)
# Out:
# Extracting EDF parameters from C:\Users\washi\OneDrive\Documents\Final Project\sub-HUP060\ses-presurgery\ieeg\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('test1.csv')
df
# Out:
#                 # C3            C4            CZ          EKG1          EKG2  \
# 0       2.140078e-03 -4.482338e-03  6.873426e-03  1.823453e-04  3.182269e-03
# 1       2.143130e-03 -4.483864e-03  6.878004e-03  1.701381e-04  3.179217e-03
# 2       2.158389e-03 -4.471656e-03  6.910048e-03  1.808194e-04  3.189899e-03
# 3       2.153811e-03 -4.476234e-03  6.906996e-03  1.716640e-04  3.179217e-03
# 4       2.146181e-03 -4.483864e-03  6.893263e-03  1.609827e-04  3.159380e-03
# ...              ...           ...           ...           ...           ...
# 188995  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188996  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188997  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188998  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188999  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
#
#                   F3            F4            F7            F8           FP1  \
# 0       1.873045e-03  9.514000e-04 -3.104448e-03  5.424582e-04  1.703670e-03
# 1       1.876097e-03  9.514000e-04 -3.090715e-03  5.470359e-04  1.709773e-03
# 2       1.891356e-03  9.636072e-04 -3.078508e-03  5.561913e-04  1.720455e-03
# 3       1.885252e-03  9.590295e-04 -3.083085e-03  5.516136e-04  1.712825e-03
# 4       1.877623e-03  9.529259e-04 -3.092241e-03  5.455100e-04  1.709773e-03
# ...              ...           ...           ...           ...           ...
# 188995  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188996  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188997  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188998  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188999  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
#
#         ...         RPFb1         RPFb2         RPFb3         RPFc1  \
# 0       ... -2.510109e-04  4.254978e-03 -4.839399e-03 -1.992065e-03
# 1       ... -2.403296e-04  4.262608e-03 -4.830243e-03 -1.996643e-03
# 2       ... -2.235447e-04  4.280919e-03 -4.818036e-03 -1.981384e-03
# 3       ... -2.220188e-04  4.279393e-03 -4.822614e-03 -1.985962e-03
# 4       ... -2.281224e-04  4.279393e-03 -4.824140e-03 -1.985962e-03
# ...     ...           ...           ...           ...           ...
# 188995  ...  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188996  ...  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188997  ...  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188998  ...  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188999  ...  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
#
#                RPFc2         RPFc3            T3            T4            T5  \
# 0      -4.901961e-03  3.902495e-03 -1.992065e-03  1.945525e-04 -2.764172e-03
# 1      -4.898909e-03  3.904021e-03 -1.993591e-03  1.899748e-04 -2.765698e-03
# 2      -4.879072e-03  3.919280e-03 -1.978332e-03  2.052338e-04 -2.756542e-03
# 3      -4.877546e-03  3.916228e-03 -1.985962e-03  1.945525e-04 -2.761120e-03
# 4      -4.877546e-03  3.914702e-03 -1.990539e-03  1.915007e-04 -2.764172e-03
# ...              ...           ...           ...           ...           ...
# 188995  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188996  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188997  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188998  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
# 188999  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07  7.629511e-07
#
#                   T6
# 0      -4.251926e-03
# 1      -4.254978e-03
# 2      -4.244297e-03
# 3      -4.247349e-03
# 4      -4.247349e-03
# ...              ...
# 188995  7.629511e-07
# 188996  7.629511e-07
# 188997  7.629511e-07
# 188998  7.629511e-07
# 188999  7.629511e-07
#
# [189000 rows x 59 columns]

# %%
import pandas as pd
from HFODetector import ste

edf_path = 'C:\\Users\\washi\\OneDrive\\Documents\\Final Project\\sub-HUP060\\ses-presurgery\\ieeg\\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf' #change this to your edf path
detector = ste.STEDetector(
            # filter paramters
            sample_freq=500.0, 
            filter_freq=[80, 200],
            # STE parameters
            rms_window=3*1e-3, 
            min_window=6*1e-3, 
            min_gap=10 * 1e-3, 
            epoch_len=600, 
            min_osc=6, 
            rms_thres=5, 
            peak_thres=3,
            # multi-processing parameters
            n_jobs=4, #Caution: this depends on how many core you CPU has
            front_num=1
            )

channel_names, start_end = detector.detect_edf(edf_path)

print(channel_names)
#prints the detected HFO intervals per channel
print(start_end)
# Out:
# Extracting EDF parameters from C:\Users\washi\OneDrive\Documents\Final Project\sub-HUP060\ses-presurgery\ieeg\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 100%|██████████| 58.0/58.0 [00:04<00:00, 11.8it/s]
# ['C3' 'C4' 'CZ' 'EKG1' 'EKG2' 'F3' 'F4' 'F7' 'F8' 'FP1' 'FP2' 'FZ' 'LAF1'
#  'LAF2' 'LAF3' 'LAF4' 'O1' 'O2' 'P3' 'P4' 'PZ' 'RA1' 'RA2' 'RA3' 'RA4'
#  'RAFa1' 'RAFa2' 'RAFa3' 'RAFa4' 'RAFb1' 'RAFb2' 'RAFb3' 'RAFb4' 'RAFc1'
#  'RAFc2' 'RAFc3' 'RAFc4' 'RAFd1' 'RAFd2' 'RAFd3' 'RAFd4' 'RH1' 'RH2' 'RH3'
#  'RH4' 'RPFa1' 'RPFa2' 'RPFa3' 'RPFa4' 'RPFb1' 'RPFb2' 'RPFb3' 'RPFc1'
#  'RPFc2' 'RPFc3' 'T3' 'T4' 'T5' 'T6']
# [list([[np.int64(91126), np.int64(91156)], [np.int64(91452), np.int64(91465)], [np.int64(97340), np.int64(97354)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188937)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(86905), np.int64(86931)], [np.int64(88386), np.int64(88411)]])
#  list([[np.int64(86921), np.int64(86942)], [np.int64(88387), np.int64(88404)]])
#  list([]) list([])
#  list([[np.int64(86399), np.int64(86416)], [np.int64(87547), np.int64(87560)], [np.int64(92076), np.int64(92088)]])
#  list([]) list([[np.int64(72547), np.int64(72561)]])
#  list([[np.int64(72463), np.int64(72487)]]) list([])
#  list([[np.int64(0), np.int64(28)], [np.int64(188891), np.int64(188946)]])
#  list([])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188900), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188937)]])
#  list([]) list([])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188902), np.int64(188937)]])
#  list([]) list([]) list([[np.int64(188907), np.int64(188932)]]) list([])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188902), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188900), np.int64(188937)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188937)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([])
#  list([[np.int64(0), np.int64(28)], [np.int64(188891), np.int64(188946)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188900), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188907), np.int64(188932)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188902), np.int64(188937)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188900), np.int64(188937)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(73919), np.int64(73933)], [np.int64(188907), np.int64(188932)]])
#  list([])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188937)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188941)]])
#  list([[np.int64(188907), np.int64(188932)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188898), np.int64(188937)]])
#  list([[np.int64(0), np.int64(19)], [np.int64(188907), np.int64(188932)]])
#  list([[np.int64(86398), np.int64(86410)]]) list([])
#  list([[np.int64(86574), np.int64(86588)]]) list([])]

# %%
# channel_names is a list that is the same length as the number of channels in the edf
# start_end is a nested list with the same length as channel_names. start_end[i][j][0] and start_end[i][j][1] 
# will give the start and end index respectively for the jth detected HFO in channel 
print(len(channel_names), len(start_end))
# Out:
# 59 59

# %%
# convert to pandas dataframe
channel_names = np.concatenate([[channel_names[i]]*len(start_end[i]) for i in range(len(channel_names))])
#removes channels that have no HFO detections
start_end = [start_end[i] for i in range(len(start_end)) if len(start_end[i])>0]
#combines all detected start-end time intervals into one big list
start_end = np.concatenate(start_end)

#Creates a table (DataFrame) with three columns:
# "channel": channel name where the HFO was detected.
#"start": start time (or sample index) of the detected HFO.
#"end": end time (or sample index) of the detected HFO.
HFO_ste_df = pd.DataFrame({"channel":channel_names,"start":start_end[:,0],"end":start_end[:,1]})

# %%
HFO_ste_df.head(10)
#channel = which EEG channel detected the HFO
#start = when it started
#end = when it ended
# Out:
#   channel   start     end
# 0      C3   91126   91156
# 1      C3   91452   91465
# 2      C3   97340   97354
# 3      C4       0      19
# 4      C4  188898  188937
# 5      CZ  188907  188932
# 6    EKG1   86905   86931
# 7    EKG1   88386   88411
# 8    EKG2   86921   86942
# 9    EKG2   88387   88404

# %%
HFO_ste_df.to_csv("HFO_ste.csv", index=False)
print(HFO_ste_df.head())
# Out:
#   channel   start     end
# 0      C3   91126   91156
# 1      C3   91452   91465
# 2      C3   97340   97354
# 3      C4       0      19
# 4      C4  188898  188937

# %% [markdown]
# MNI Detector

# %%
from HFODetector import mni

edf_path = 'C:\\Users\\washi\\OneDrive\\Documents\\Final Project\\sub-HUP060\\ses-presurgery\\ieeg\\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf' #change this to your edf path
sample_freq=2000 #change this to your sample frequency
detector = mni.MNIDetector(sample_freq, filter_freq=[80, 500], 
            epoch_time=10, epo_CHF=60, per_CHF=95/100, 
            min_win=10*1e-3, min_gap=10*1e-3, thrd_perc=99.9999/100, 
            base_seg=125*1e-3, base_shift=0.5, base_thrd=0.67, base_min=5,
            n_jobs=32, front_num=1)
channel_names, start_end = detector.detect_edf(edf_path)
channel_names = np.concatenate([[channel_names[i]]*len(start_end[i]) for i in range(len(channel_names))])
start_end = [start_end[i] for i in range(len(start_end)) if len(start_end[i])>0]
start_end = np.concatenate(start_end)
HFO_mni_df = pd.DataFrame({"channel":channel_names,"start":start_end[:,0],"end":start_end[:,1]})
# Out:
# Extracting EDF parameters from C:\Users\washi\OneDrive\Documents\Final Project\sub-HUP060\ses-presurgery\ieeg\sub-HUP060_ses-presurgery_task-ictal_acq-seeg_run-01_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 100%|██████████| 58.0/58.0 [01:31<00:00, 1.58s/it]

# %%
HFO_mni_df.head(10)
HFO_mni_df.to_csv("HFO_mni.csv", index=False)
print(HFO_mni_df.head())
# Out:
#   channel   start     end
# 0      C3       0      32
# 1      C3  181625  189000
# 2      C4       0      43
# 3      C4  177875  189000
# 4      CZ       0      56
